# %%
import numpy as np
from typing import List
from scipy.stats import levy_stable
import matplotlib.pyplot as plt
from ecit import *

# %%
for p_ in [p_alpha05, p_cauchy, p_alpha15, p_gaussian, p_mean]:
    re = []
    for i in range(10000):
        pl = np.random.uniform(0,1,4)
        re.append(p_(pl))

    plt.figure(figsize=(12,6),dpi = 300)
    plt.hist(re, density=True)
    plt.show()

# %%
for p_ in [p_alpha05, p_cauchy, p_alpha15, p_gaussian, p_mean]:
    re = []
    for i in range(10000):
        np.random.seed(i)
        pl = np.random.uniform(0,1,4)
        re.append(p_(pl))

    plt.figure(figsize=(12,6),dpi = 300)
    plt.hist(re, density=True)
    plt.show()
