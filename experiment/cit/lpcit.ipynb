# %%
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.simplefilter("ignore", category=ConvergenceWarning)
from sklearn.gaussian_process import GaussianProcessRegressor
from citSimu import *

np.random.seed(1)
random.seed(1)

ensCIT = [(lpcit, 1, p_alpha2), (lpcit, 400, p_alpha2), (lpcit, 400, p_alpha175)]
results = ecitSimulate(ensCIT)
# Out:
#   800, gaussian,   1,   p_alpha2: 100%|██████████| 3/3 [1:03:15<00:00, 1265.15s/it]
#   800, gaussian, 400,   p_alpha2: 100%|██████████| 3/3 [1:22:39<00:00, 1653.19s/it]
#   800, gaussian, 400, p_alpha175:   0%|          | 0/3 [00:00<?, ?it/s]
# Retries times 1
#   800, gaussian, 400, p_alpha175: 100%|██████████| 3/3 [1:23:24<00:00, 1668.14s/it]
#   800,  laplace,   1,   p_alpha2: 100%|██████████| 3/3 [1:03:38<00:00, 1272.89s/it]
#   800,  laplace, 400,   p_alpha2: 100%|██████████| 3/3 [1:21:48<00:00, 1636.02s/it]
#   800,  laplace, 400, p_alpha175: 100%|██████████| 3/3 [1:22:48<00:00, 1656.12s/it]
#  1200, gaussian,   1,   p_alpha2: 100%|██████████| 3/3 [1:20:39<00:00, 1613.06s/it]
#  1200, gaussian, 400,   p_alpha2: 100%|██████████| 3/3 [2:04:02<00:00, 2480.79s/it]
#  1200, gaussian, 400, p_alpha175:   0%|          | 0/3 [00:00<?, ?it/s]
# Retries times 1
# Retries times 1
#  1200, gaussian, 400, p_alpha175: 100%|██████████| 3/3 [2:01:27<00:00, 2429.24s/it]
#  1200,  laplace,   1,   p_alpha2: 100%|██████████| 3/3 [1:22:44<00:00, 1654.81s/it]
#  1200,  laplace, 400,   p_alpha2: 100%|██████████| 3/3 [2:08:40<00:00, 2573.52s/it]
#  1200,  laplace, 400, p_alpha175: 100%|██████████| 3/3 [2:11:03<00:00, 2621.06s/it]
#  1600, gaussian,   1,   p_alpha2: 100%|██████████| 3/3 [1:28:15<00:00, 1765.27s/it]
#  1600, gaussian, 400,   p_alpha2: 100%|██████████| 3/3 [2:44:19<00:00, 3286.53s/it]
#  1600, gaussian, 400, p_alpha175: 100%|██████████| 3/3 [2:43:05<00:00, 3261.88s/it]
#  1600,  laplace,   1,   p_alpha2: 100%|██████████| 3/3 [2:09:49<00:00, 2596.41s/it]
#  1600,  laplace, 400,   p_alpha2: 100%|██████████| 3/3 [4:15:33<00:00, 5111.31s/it]
#  1600,  laplace, 400, p_alpha175:   0%|          | 0/3 [00:00<?, ?it/s]
# Retries times 1
#  1600,  laplace, 400, p_alpha175: 100%|██████████| 3/3 [4:48:56<00:00, 5778.91s/it]

# %%
table = [
    [round(item, 3) if isinstance(item, float) else item for item in sublist]
    for sublist in results
]

for i, row in enumerate(table):
    if (i)%3 == 0: print('-'*100)
    print("{:<5} {:<8} {:<21} | {:<6.3f} {:<6.3f} | {:<6.3f} {:<6.3f} | {:<6.3f} {:<6.3f}".format(*row))
# Out:
# ----------------------------------------------------------------------------------------------------
# 800   Gaussian lpcit1p_alpha2        | 0.065  0.740  | 0.052  0.627  | 0.016  0.423
# 800   Gaussian lpcit400p_alpha2      | 0.045  0.720  | 0.033  0.662  | 0.015  0.423
# 800   Gaussian lpcit400p_alpha175    | 0.051  0.745  | 0.030  0.681  | 0.021  0.436
# ----------------------------------------------------------------------------------------------------
# 800   Laplace  lpcit1p_alpha2        | 0.055  0.714  | 0.042  0.636  | 0.017  0.422
# 800   Laplace  lpcit400p_alpha2      | 0.046  0.730  | 0.039  0.647  | 0.021  0.449
# 800   Laplace  lpcit400p_alpha175    | 0.050  0.719  | 0.037  0.637  | 0.019  0.434
# ----------------------------------------------------------------------------------------------------
# 1200  Gaussian lpcit1p_alpha2        | 0.054  0.742  | 0.054  0.659  | 0.021  0.422
# 1200  Gaussian lpcit400p_alpha2      | 0.054  0.767  | 0.026  0.669  | 0.017  0.418
# 1200  Gaussian lpcit400p_alpha175    | 0.042  0.755  | 0.031  0.675  | 0.013  0.447
# ----------------------------------------------------------------------------------------------------
# 1200  Laplace  lpcit1p_alpha2        | 0.065  0.762  | 0.034  0.631  | 0.028  0.430
# 1200  Laplace  lpcit400p_alpha2      | 0.050  0.747  | 0.041  0.678  | 0.015  0.436
# 1200  Laplace  lpcit400p_alpha175    | 0.039  0.755  | 0.034  0.690  | 0.013  0.464
# ----------------------------------------------------------------------------------------------------
# 1600  Gaussian lpcit1p_alpha2        | 0.072  0.744  | 0.055  0.674  | 0.024  0.415
# 1600  Gaussian lpcit400p_alpha2      | 0.053  0.754  | 0.023  0.696  | 0.015  0.423
# 1600  Gaussian lpcit400p_alpha175    | 0.035  0.755  | 0.023  0.707  | 0.012  0.465
# ----------------------------------------------------------------------------------------------------
# 1600  Laplace  lpcit1p_alpha2        | 0.075  0.755  | 0.062  0.663  | 0.018  0.421
# 1600  Laplace  lpcit400p_alpha2      | 0.045  0.772  | 0.040  0.714  | 0.014  0.453
# 1600  Laplace  lpcit400p_alpha175    | 0.043  0.750  | 0.037  0.716  | 0.009  0.482

# %%
from citSimu import *
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.simplefilter("ignore", category=ConvergenceWarning)
import seaborn as sns
sns.set()

np.random.seed(1)
random.seed(1)

ensCIT = [(lpcit, 1, p_alpha2),
          (lpcit, 400, p_alpha175),
          (lpcit, 400, p_alpha2)]

results = ecitSimulateDZ(ensCIT)

plot_dz(results)

results
# Out:
# {'lpcit1p_alpha2': [[0.067, 0.072, 0.063, 0.051, 0.056],
#   [0.648, 0.619, 0.567, 0.57, 0.565],
#   [4077.6243529319763,
#    5129.542592763901,
#    5296.932023048401,
#    5322.445837974548,
#    5313.446406126022]],
#  'lpcit400p_alpha175': [[0.032, 0.026, 0.029, 0.028, 0.037],
#   [0.692, 0.645, 0.63, 0.595, 0.582],
#   [5574.6783900260925,
#    6825.967785835266,
#    7258.1425132751465,
#    7553.365508079529,
#    7448.319311141968]],
#  'lpcit400p_alpha2': [[0.023, 0.039, 0.027, 0.035, 0.027],
#   [0.679, 0.626, 0.634, 0.596, 0.558],
#   [4169.272380113602,
#    4016.107684135437,
#    4441.73436498642,
#    4729.689428806305,
#    4870.860066175461]]}
