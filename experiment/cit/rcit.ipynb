# %%
from citSimu import *

np.random.seed(1)
random.seed(1)

ensCIT = [(rcit, 1, p_alpha2), (rcit, 400, p_alpha175), (rcit, 400, p_alpha2)]
results = ecitSimulate(ensCIT)
# Out:
#   800, gaussian,   1,   p_alpha2: 100%|██████████| 3/3 [01:44<00:00, 34.75s/it]
#   800, gaussian, 400, p_alpha175: 100%|██████████| 3/3 [04:39<00:00, 93.32s/it]
#   800, gaussian, 400,   p_alpha2: 100%|██████████| 3/3 [02:24<00:00, 48.06s/it]
#   800,  laplace,   1,   p_alpha2: 100%|██████████| 3/3 [01:43<00:00, 34.34s/it]
#   800,  laplace, 400, p_alpha175: 100%|██████████| 3/3 [04:19<00:00, 86.57s/it]
#   800,  laplace, 400,   p_alpha2: 100%|██████████| 3/3 [02:21<00:00, 47.11s/it]
#  1200, gaussian,   1,   p_alpha2: 100%|██████████| 3/3 [01:46<00:00, 35.66s/it]
#  1200, gaussian, 400, p_alpha175: 100%|██████████| 3/3 [06:33<00:00, 131.03s/it]
#  1200, gaussian, 400,   p_alpha2: 100%|██████████| 3/3 [03:35<00:00, 71.86s/it]
#  1200,  laplace,   1,   p_alpha2: 100%|██████████| 3/3 [01:46<00:00, 35.40s/it]
#  1200,  laplace, 400, p_alpha175: 100%|██████████| 3/3 [06:29<00:00, 129.93s/it]
#  1200,  laplace, 400,   p_alpha2: 100%|██████████| 3/3 [03:29<00:00, 69.94s/it]
#  1600, gaussian,   1,   p_alpha2: 100%|██████████| 3/3 [01:53<00:00, 37.77s/it]
#  1600, gaussian, 400, p_alpha175: 100%|██████████| 3/3 [08:47<00:00, 175.89s/it]
#  1600, gaussian, 400,   p_alpha2: 100%|██████████| 3/3 [04:44<00:00, 94.77s/it]
#  1600,  laplace,   1,   p_alpha2: 100%|██████████| 3/3 [02:02<00:00, 40.94s/it]
#  1600,  laplace, 400, p_alpha175: 100%|██████████| 3/3 [09:01<00:00, 180.49s/it]
#  1600,  laplace, 400,   p_alpha2: 100%|██████████| 3/3 [04:43<00:00, 94.63s/it]

# %%
table = [
    [round(item, 3) if isinstance(item, float) else item for item in sublist]
    for sublist in results
]

for i, row in enumerate(table):
    if (i)%3 == 0: print('-'*100)
    print("{:<5} {:<8} {:<21} | {:<6.3f} {:<6.3f} | {:<6.3f} {:<6.3f} | {:<6.3f} {:<6.3f}".format(*row))
# Out:
# ----------------------------------------------------------------------------------------------------
# 800   Gaussian rcit1p_alpha2         | 0.037  0.801  | 0.041  0.724  | 0.042  0.512
# 800   Gaussian rcit400p_alpha175     | 0.041  0.833  | 0.039  0.768  | 0.033  0.545
# 800   Gaussian rcit400p_alpha2       | 0.060  0.852  | 0.048  0.786  | 0.045  0.562
# ----------------------------------------------------------------------------------------------------
# 800   Laplace  rcit1p_alpha2         | 0.043  0.801  | 0.056  0.688  | 0.019  0.521
# 800   Laplace  rcit400p_alpha175     | 0.046  0.803  | 0.048  0.720  | 0.045  0.536
# 800   Laplace  rcit400p_alpha2       | 0.058  0.796  | 0.051  0.745  | 0.047  0.552
# ----------------------------------------------------------------------------------------------------
# 1200  Gaussian rcit1p_alpha2         | 0.037  0.845  | 0.037  0.765  | 0.037  0.548
# 1200  Gaussian rcit400p_alpha175     | 0.046  0.891  | 0.042  0.823  | 0.042  0.623
# 1200  Gaussian rcit400p_alpha2       | 0.054  0.906  | 0.066  0.838  | 0.044  0.609
# ----------------------------------------------------------------------------------------------------
# 1200  Laplace  rcit1p_alpha2         | 0.049  0.824  | 0.046  0.730  | 0.041  0.532
# 1200  Laplace  rcit400p_alpha175     | 0.067  0.860  | 0.053  0.792  | 0.040  0.578
# 1200  Laplace  rcit400p_alpha2       | 0.060  0.869  | 0.068  0.822  | 0.040  0.622
# ----------------------------------------------------------------------------------------------------
# 1600  Gaussian rcit1p_alpha2         | 0.039  0.866  | 0.042  0.799  | 0.037  0.551
# 1600  Gaussian rcit400p_alpha175     | 0.048  0.932  | 0.047  0.870  | 0.043  0.642
# 1600  Gaussian rcit400p_alpha2       | 0.069  0.931  | 0.069  0.883  | 0.065  0.681
# ----------------------------------------------------------------------------------------------------
# 1600  Laplace  rcit1p_alpha2         | 0.046  0.862  | 0.043  0.757  | 0.038  0.553
# 1600  Laplace  rcit400p_alpha175     | 0.062  0.913  | 0.053  0.849  | 0.039  0.639
# 1600  Laplace  rcit400p_alpha2       | 0.071  0.916  | 0.060  0.882  | 0.060  0.673

# %%
from citSimu import *
import seaborn as sns
sns.set()

np.random.seed(1)
random.seed(1)

ensCIT = [(rcit, 1, p_alpha2),
          (rcit, 400, p_alpha175),
          (rcit, 400, p_alpha2)]

results = ecitSimulateDZ(ensCIT, n=1200)

plot_dz(results)

results
# Out:
# {'rcit1p_alpha2': [[0.046, 0.048, 0.044, 0.044, 0.058],
#   [0.782, 0.728, 0.651, 0.634, 0.647],
#   [42.30490016937256,
#    42.45851278305054,
#    45.781434059143066,
#    44.473085165023804,
#    51.4003381729126]],
#  'rcit400p_alpha175': [[0.043, 0.067, 0.087, 0.086, 0.116],
#   [0.815, 0.791, 0.76, 0.742, 0.731],
#   [165.99466586112976,
#    163.77140522003174,
#    171.3154580593109,
#    168.66969776153564,
#    167.53090405464172]],
#  'rcit400p_alpha2': [[0.055, 0.08, 0.106, 0.118, 0.123],
#   [0.838, 0.813, 0.798, 0.791, 0.778],
#   [102.15597891807556,
#    91.67953729629517,
#    96.46171021461487,
#    130.0971257686615,
#    142.37973880767822]]}
