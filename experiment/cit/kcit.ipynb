# %%
from citSimu import *

np.random.seed(1)
random.seed(1)

ensCIT = [(kcit, 1, p_alpha2), (kcit, 400, p_alpha2), (kcit, 400, p_alpha175)]
results = ecitSimulate(ensCIT)
# Out:
#   800, gaussian,   1,   p_alpha2: 100%|██████████| 3/3 [28:42<00:00, 574.28s/it]
#   800, gaussian, 400,   p_alpha2: 100%|██████████| 3/3 [12:46<00:00, 255.45s/it]
#   800, gaussian, 400, p_alpha175: 100%|██████████| 3/3 [14:33<00:00, 291.27s/it]
#   800,  laplace,   1,   p_alpha2: 100%|██████████| 3/3 [28:42<00:00, 574.23s/it]
#   800,  laplace, 400,   p_alpha2: 100%|██████████| 3/3 [12:46<00:00, 255.62s/it]
#   800,  laplace, 400, p_alpha175: 100%|██████████| 3/3 [13:58<00:00, 279.56s/it]
#  1200, gaussian,   1,   p_alpha2: 100%|██████████| 3/3 [1:17:51<00:00, 1557.02s/it]
#  1200, gaussian, 400,   p_alpha2: 100%|██████████| 3/3 [18:09<00:00, 363.03s/it]
#  1200, gaussian, 400, p_alpha175: 100%|██████████| 3/3 [21:08<00:00, 422.82s/it]
#  1200,  laplace,   1,   p_alpha2: 100%|██████████| 3/3 [1:18:27<00:00, 1569.09s/it]
#  1200,  laplace, 400,   p_alpha2: 100%|██████████| 3/3 [18:09<00:00, 363.03s/it]
#  1200,  laplace, 400, p_alpha175: 100%|██████████| 3/3 [21:08<00:00, 422.78s/it]
#  1600, gaussian,   1,   p_alpha2: 100%|██████████| 3/3 [2:49:18<00:00, 3386.18s/it]
#  1600, gaussian, 400,   p_alpha2: 100%|██████████| 3/3 [24:12<00:00, 484.29s/it]
#  1600, gaussian, 400, p_alpha175: 100%|██████████| 3/3 [28:03<00:00, 561.16s/it]
#  1600,  laplace,   1,   p_alpha2: 100%|██████████| 3/3 [2:48:25<00:00, 3368.64s/it]
#  1600,  laplace, 400,   p_alpha2: 100%|██████████| 3/3 [24:19<00:00, 486.39s/it]
#  1600,  laplace, 400, p_alpha175: 100%|██████████| 3/3 [28:05<00:00, 561.84s/it]

# %%
table = [
    [round(item, 3) if isinstance(item, float) else item for item in sublist]
    for sublist in results
]

for i, row in enumerate(table):
    if (i)%3 == 0: print('-'*100)
    print("{:<5} {:<8} {:<21} | {:<6.3f} {:<6.3f} | {:<6.3f} {:<6.3f} | {:<6.3f} {:<6.3f}".format(*row))
# Out:
# ----------------------------------------------------------------------------------------------------
# 800   Gaussian kcit1p_alpha2         | 0.046  0.878  | 0.056  0.817  | 0.046  0.563
# 800   Gaussian kcit400p_alpha2       | 0.048  0.909  | 0.039  0.865  | 0.033  0.638
# 800   Gaussian kcit400p_alpha175     | 0.047  0.902  | 0.044  0.860  | 0.031  0.620
# ----------------------------------------------------------------------------------------------------
# 800   Laplace  kcit1p_alpha2         | 0.043  0.881  | 0.038  0.812  | 0.034  0.585
# 800   Laplace  kcit400p_alpha2       | 0.052  0.884  | 0.037  0.838  | 0.036  0.632
# 800   Laplace  kcit400p_alpha175     | 0.042  0.874  | 0.046  0.817  | 0.043  0.596
# ----------------------------------------------------------------------------------------------------
# 1200  Gaussian kcit1p_alpha2         | 0.045  0.907  | 0.034  0.835  | 0.036  0.645
# 1200  Gaussian kcit400p_alpha2       | 0.042  0.931  | 0.044  0.889  | 0.038  0.728
# 1200  Gaussian kcit400p_alpha175     | 0.055  0.937  | 0.037  0.878  | 0.030  0.702
# ----------------------------------------------------------------------------------------------------
# 1200  Laplace  kcit1p_alpha2         | 0.054  0.901  | 0.054  0.825  | 0.036  0.643
# 1200  Laplace  kcit400p_alpha2       | 0.055  0.911  | 0.035  0.881  | 0.039  0.700
# 1200  Laplace  kcit400p_alpha175     | 0.058  0.914  | 0.048  0.895  | 0.033  0.706
# ----------------------------------------------------------------------------------------------------
# 1600  Gaussian kcit1p_alpha2         | 0.063  0.923  | 0.036  0.839  | 0.032  0.639
# 1600  Gaussian kcit400p_alpha2       | 0.058  0.958  | 0.053  0.918  | 0.046  0.804
# 1600  Gaussian kcit400p_alpha175     | 0.056  0.947  | 0.047  0.909  | 0.037  0.787
# ----------------------------------------------------------------------------------------------------
# 1600  Laplace  kcit1p_alpha2         | 0.047  0.918  | 0.041  0.839  | 0.034  0.662
# 1600  Laplace  kcit400p_alpha2       | 0.065  0.949  | 0.043  0.920  | 0.030  0.804
# 1600  Laplace  kcit400p_alpha175     | 0.071  0.927  | 0.054  0.897  | 0.045  0.752

# %%
from citSimu import *
import seaborn as sns
sns.set()

np.random.seed(1)
random.seed(1)

ensCIT = [(kcit, 1, p_alpha2),
          (kcit, 400, p_alpha175),
          (kcit, 400, p_alpha2)]

results = ecitSimulateDZ(ensCIT, n=1200)

plot_dz(results)

results
# Out:
# {'kcit1p_alpha2': [[0.045, 0.058, 0.127, 0.275, 0.461],
#   [0.851, 0.818, 0.823, 0.783, 0.79],
#   [1623.392642736435,
#    1617.6515629291534,
#    1713.9977281093597,
#    1724.2876369953156,
#    1730.7141671180725]],
#  'kcit400p_alpha175': [[0.043, 0.071, 0.098, 0.199, 0.353],
#   [0.879, 0.866, 0.846, 0.827, 0.828],
#   [427.918338060379,
#    436.235533952713,
#    469.0653212070465,
#    484.05782318115234,
#    482.9001410007477]],
#  'kcit400p_alpha2': [[0.053, 0.066, 0.12, 0.274, 0.4],
#   [0.895, 0.891, 0.877, 0.839, 0.842],
#   [365.2109839916229,
#    381.6407780647278,
#    410.48255681991577,
#    416.592777967453,
#    452.4255061149597]]}
