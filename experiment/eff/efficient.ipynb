# %%
from timeSimu import *

# %%
np.random.seed(1)
random.seed(1)

result2 = ecitSimulateTime(noiseDis='t2')
result2
# Out:
# ...
# kcit, n=4000: 100%|██████████| 1000/1000 [21:20<00:00,  1.28s/it]
# {'kcit1p_alpha2': [[0.038, 0.045, 0.041, 0.039, 0.04],
#   [0.25, 0.123, 0.14, 0.102, 0.106],
#   [684.704666852951,
#    3483.1389651298523,
#    10419.609378099442,
#    23430.866311073303,
#    44133.3780169487]],
#  'rcit1p_alpha2': [[0.048, 0.03, 0.042, 0.044, 0.038],
#   [0.463, 0.427, 0.383, 0.417, 0.382],
#   [36.84195685386658,
#    41.30322504043579,
#    46.1181480884552,
#    50.42737793922424,
#    56.00177597999573]],
#  'fastkcit1p_alpha2': [[0.042, 0.031, 0.043, 0.044, 0.033],
#   [0.307, 0.184, 0.121, 0.117, 0.094],
#   [314.2048599720001,
#    587.9612801074982,
#    1233.0761642456055,
#    2025.9986772537231,
#    3185.887460708618]],
#  'kcit400p_alpha175': [[0.04, 0.046, 0.048, 0.045, 0.054],
#   [0.274, 0.148, 0.076, 0.071, 0.061],
#   [298.3346781730652,
#    594.9821829795837,
#    892.532684803009,
#    1178.6299240589142,
#    1474.474557876587]],
# ...

# %%
show_results(result2, yl=0.48)

# %%
np.random.seed(1)
random.seed(1)

resultC = ecitSimulateTime(noiseDis='cauchy')
resultC
# Out:
# ...
# kcit, n=1600:  81%|████████  | 810/1000 [45:46<10:35,  3.34s/it]/opt/anaconda3/envs/graph/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/graph/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/graph/lib/python3.10/site-packages/causallearn/utils/KCI/KCI.py:596: RuntimeWarning: invalid value encountered in scalar divide
#   k_appr = mean_appr ** 2 / var_appr
# /opt/anaconda3/envs/graph/lib/python3.10/site-packages/causallearn/utils/KCI/KCI.py:597: RuntimeWarning: invalid value encountered in scalar divide
#   theta_appr = var_appr / mean_appr
# ...
# kcit, n=2400:  18%|█▊        | 178/1000 [30:49<2:21:39, 10.34s/it]/opt/anaconda3/envs/graph/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
# ...

# %%
show_results(resultC, yl=0.18)

# %%
np.random.seed(1)
random.seed(1)

resultL = ecitSimulateTime(noiseDis='laplace')
resultL
# Out:
# ...
# fastkcit, n=4000:  20%|██        | 204/1000 [14:48<1:00:40,  4.57s/it]/opt/anaconda3/envs/graph/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# ...
# kcit, n=4000: 100%|██████████| 1000/1000 [21:00<00:00,  1.26s/it]
# {'kcit1p_alpha2': [[0.042, 0.035, 0.051, 0.05, 0.044],
#   [0.091, 0.033, 0.031, 0.017, 0.011],
#   [627.8829278945923,
#    3388.5983917713165,
#    10480.577640295029,
#    23532.664961099625,
#    45413.943403959274]],
#  'rcit1p_alpha2': [[0.041, 0.059, 0.054, 0.058, 0.053],
#   [0.134, 0.068, 0.038, 0.03, 0.029],
#   [34.41819906234741,
#    38.435497999191284,
#    42.237481117248535,
#    45.842456102371216,
#    49.7955801486969]],
#  'fastkcit1p_alpha2': [[0.058, 0.04, 0.052, 0.064, 0.075],
#   [0.084, 0.055, 0.034, 0.012, 0.012],
#   [352.9004900455475,
#    752.281081199646,
# ...

# %%
show_results(resultL, yl=0.68)
